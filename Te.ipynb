# %% [markdown]
# <a href="https://colab.research.google.com/github/Nkanga-Pedro/DevOps/blob/main/Te.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={'id':[1,2,3,4,5],'nome':['nkanga','nkanga','nkanga','nkanga','nkanga pedro']}

# %%
dt=pd.DataFrame(data)

# %%
dt
# Out:
#    id          nome
# 0   1        nkanga
# 1   2        nkanga
# 2   3        nkanga
# 3   4        nkanga
# 4   5  nkanga pedro
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1871776230928199376 = autoviz.get_registered_df('df_1871776230928199376')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1871776230928199376, *['id'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
dt.head()
# Out:
#    id    nome
# 0   1  nkanga
# 1   2  nkanga
# 2   3  nkanga
# 3   4  nkanga
# 4   5  nkanga
